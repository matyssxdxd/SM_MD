# %% [markdown]
# # Mājas darbs 1 - Nelineāro vienādojumu saknes
#
# Lielgabala lode tiek izšauta no zemes leņķī $𝜃$ ar sākuma ātrumu $v_0$. Lielgabala lodes augstumu $h(t)$ jebkurā brīdī $t$ var modelēt ar šādu vienādojumu, pieņemot, ka nav gaisa pretestības:
#
# $$ h(t) = v_0 sin(θ)t - \frac{1}{2}gt^2 $$
#
# Kur:
# * $g$ — brīvas krišanas paātrinājums, $g = 9,81 m/s^2$
# * $θ$ - ir leņķis grādos
# * $v_0$ - ir sākotnējais ātrums, metros sekundē.
#
# Varianti:
#
# 1. Bisection, $v_0=50m/s$, $θ = 45°$, $H = 30m$
# 2. False-Position, $v_0=60m/s$, $θ = 30°$, $H = 30m$
# 3. Secant method, $v_0=50m/s$, $θ = 55°$, $H = 50m$

# %% [markdown]
# 1.1. Definēt funkciju $h(t)$ un attēlot lodes augstuma izmaiņu laikā attiecībā pret zemi.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Nodefinēju konstantus mainīgos, kas ir doti priekš variantiem
V_ZERO = 50
ANGLE_THETA = 45
GRAVITY = 9.81
TARGET_HEIGHT = 30

# Izveidoju funkciju h(t), kas veidota pēc augšā dotās formulas
def h(t):
    # Šeit es pārveidoju ANGLE_THETA uz radiāniem, jo funkcija math.sin() sagaida input radiānos
    return V_ZERO * math.sin(math.radians(ANGLE_THETA)) * t - 0.5 * GRAVITY * t ** 2

# Izveidoju numpy array ar vērtībām 0 līdz 10 ar soli 0.1, lai plot nebūtu saraustīts, šīs būtu laika vērtības funckijai
x_points = np.arange(0.0, 10.0, 0.1)
y_points = []

# Eju cauri katrai laika vērtībai un aprēķinu lodes augstumu dotajā laika sprīdī, ja tas ir lielāks par 0, pievienoju to y_points masīvam
# lai netiktu saglabātas vērtības, kas teorētiski nozīmētu, ka lode iet zemāk par zemi
for t in x_points:
    height = h(t)
    if height > 0:
        y_points.append(height)

# Pārveidoju x_points, lai nodzēstu tos laika sprīžus, kad h bija mazāks par 0
x_points_valid = x_points[:len(y_points)]

# Izveidoju plot ar punktiem
plt.plot(x_points_valid, y_points)
plt.xlabel('Time (s)')
plt.ylabel('Height (m)')
plt.show()

# %% [markdown]
# 1.2. Noskaidrot kopējo laiku $T$, ko lode pavada gaisā.

# %%
# https://en.wikipedia.org/wiki/Projectile_motion atradu šo formulu
total_airtime = (2 * V_ZERO * math.sin(math.radians(ANGLE_THETA))) / GRAVITY
print(total_airtime)
# Out:
# 8.673838170582247

# %% [markdown]
# 1.3. Atrast laika mirkli $t$, pie kura lode attrodas $H$ metrus virs zemes.

# %% [markdown]
# 1.4. Atrast maksimālo sasniegto augstumu $H_{max}$

# %%
# https://en.wikipedia.org/wiki/Projectile_motion arī šeit atradu formulu
max_height = (V_ZERO**2 * math.sin(math.radians(ANGLE_THETA)**2) / (2 * GRAVITY))
print(max_height)
# Out:
# 73.70907101867455
